# %% [markdown]
# # Zero-Shot Voice Cloning on Google Colab
#
# This notebook runs a web interface for high-quality, zero-shot voice cloning using Coqui TTS (XTTS-v2).

# %%
# Cell 1: Check GPU runtime and print status
import subprocess

try:
    gpu_info = subprocess.check_output('nvidia-smi', shell=True).decode('utf-8')
    print("GPU is available! Status:\n")
    print(gpu_info)
except Exception as e:
    print("WARNING: GPU is not available or not configured correctly.")
    print("Please go to Runtime > Change runtime type and select 'T4 GPU' or another GPU option.")

# %%
# Cell 2: Install required libraries
# !pip install -r requirements.txt

# %%
# Cell 3: Run the Gradio app with share=True to generate a public link
import os
os.environ['GRADIO_SHARE'] = '1'
# !python app.py
